# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.8.1.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 3.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.3.5)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-terrier) (4.64.0)
# Collecting pyjnius~=1.3.0
#   Downloading pyjnius-1.3.0-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 33.7 MB/s
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 6.8 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.0)
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.1.0)
# Collecting nptyping==1.4.4
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from python-terrier) (8.12.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.1-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 48.7 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.10.2)
# Collecting ir_measures>=0.2.0
#   Downloading ir_measures-0.3.0.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 3.8 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.3.4)
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.0 MB/s
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 50.1 MB/s
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.1.tar.gz (5.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting lz4>=3.1.1
#   Downloading lz4-4.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 42.9 MB/s
# Collecting lxml>=4.5.2
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 37.9 MB/s
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.6.3)
# Collecting ijson>=3.1.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 47.9 MB/s
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 49.5 MB/s
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp37-cp37m-manylinux2010_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.6 MB/s
# Collecting pytrec-eval-terrier==0.5.2
#   Downloading pytrec_eval_terrier-0.5.2-cp37-cp37m-manylinux2010_x86_64.whl (287 kB)
#      |████████████████████████████████| 287 kB 54.6 MB/s
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.10.tar.gz (31 kB)
# Collecting pyndeval>=0.0.2
#   Downloading pyndeval-0.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.4 MB/s
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (1.15.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (0.29.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (3.0.4)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->python-terrier) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation->python-terrier) (3.0.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2022.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->python-terrier) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->python-terrier) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->python-terrier) (0.5.2)
# Building wheels for collected packages: python-terrier, ir-measures, cwl-eval, cbor, unlzw3, warc3-wet-clueweb09, chest, wget
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.8.1-py3-none-any.whl size=104091 sha256=a5031a85e137ef2efc9f6e088fca7f43ad38a1b0cc5ffb2693682c9890b3325b
#   Stored in directory: /root/.cache/pip/wheels/09/e5/f5/2f28a11314bac89a683eb2a12aed802a7da27e4318ffbff4a8
#   Building wheel for ir-measures (setup.py) ... done
#   Created wheel for ir-measures: filename=ir_measures-0.3.0-py3-none-any.whl size=60161 sha256=a495e8235cb78e78a666d7b23ecc62dda6618a9106862bf7378072bc18b03a1a
#   Stored in directory: /root/.cache/pip/wheels/5b/9f/4e/40e81c8819bb3e6dd35336b2f0937c76f141b48cba1ad192ac
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.10-py3-none-any.whl size=37797 sha256=3076c4b638b5044444cb70d627f132e0e59642c79baa285de7e41cdc1b653307
#   Stored in directory: /root/.cache/pip/wheels/ff/e9/ff/d2b6d72d9feb0d0b1b11aacfaf5cd866717034615c2d194093
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp37-cp37m-linux_x86_64.whl size=51302 sha256=efc765f225e735ef7f815f352bfb6f705b05cae7cb95fa87019a7e2532184ec9
#   Stored in directory: /root/.cache/pip/wheels/19/77/49/c9c2c8dc5848502e606e8579d0bbda18b850fb056a6c62239d
#   Building wheel for unlzw3 (PEP 517) ... done
#   Created wheel for unlzw3: filename=unlzw3-0.2.1-py3-none-any.whl size=6082 sha256=a14e1405d9ba38c7fd7e6432e39b821360155c58ecf429e63e329ebb5238911c
#   Stored in directory: /root/.cache/pip/wheels/e1/3c/d9/e33962c8aad8999dc5560b6e71baafa2335c269f532f5e176a
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18922 sha256=e854bb83993cc7a50a4d8a55e71d7e859ab7403046a352dc36ffe17fefefa5e5
#   Stored in directory: /root/.cache/pip/wheels/42/d4/3c/7c2b0c3d400ad744e4db69f2fde166655da2ed2198bfc02db6
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7634 sha256=ede292e03a5115c6f445cca411b42e4eeae6beee22ba3c13ca2310693df47e93
#   Stored in directory: /root/.cache/pip/wheels/fc/f5/b9/c436e11300809e6b40d46a5d2592fb0bff89e0712f2e878dc7
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=c1d6a102d4ae121b9786f761afd6daced16287bf3b621f76d28b38b051e56751
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built python-terrier ir-measures cwl-eval cbor unlzw3 warc3-wet-clueweb09 chest wget
# Installing collected packages: cbor, zlib-state, warc3-wet-clueweb09, warc3-wet, unlzw3, typish, trec-car-tools, pyyaml, pytrec-eval-terrier, pyndeval, pyautocorpus, multiset, lz4, lxml, ijson, cwl-eval, wget, pyjnius, nptyping, matchpy, ir-measures, ir-datasets, deprecation, chest, python-terrier
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.10 deprecation-2.1.0 ijson-3.1.4 ir-datasets-0.5.1 ir-measures-0.3.0 lxml-4.8.0 lz4-4.0.0 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.8 pyjnius-1.3.0 pyndeval-0.0.2 python-terrier-0.8.1 pytrec-eval-terrier-0.5.2 pyyaml-6.0 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.1 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5

# %%
import pyterrier as pt
import pandas as pd
import os
from pyterrier.measures import *
import re

# %%
foodresults = pd.read_csv("foodresults.csv", encoding="latin-1")
index_result = pd.read_csv("index_result.csv")
df = pd.read_csv("dataset_with_relevance.csv",encoding="latin-1")

# %%
if not pt.started():
  pt.init()
# Out:
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.1 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %%
import re
s="sdfgfs$%$#%#$9998 sdfg"
word1 = " ".join(re.findall("[a-zA-Z]+", s))
word1
# Out:
# 'sdfgfs sdfg'

# %%
data=[]
for index,row in df.iterrows():
  query = " ".join(re.findall("[a-zA-Z]+", row["query"]))
  recipe_id = row["recipe_id"]
  recipe_name = " ".join(re.findall("[a-zA-Z]+", row["recipe_name"]))
  Relevance = row["Relevance"]
  ingredients = " ".join(re.findall("[a-zA-Z]+", str(row["ingredients"])))
  recipe = " ".join(re.findall("[a-zA-Z]+", row["recipe"]))
  rate = row["rate"]
  views = row["views"]
  description = " ".join(re.findall("[a-zA-Z]+", row["description"]))
  keywords = " ".join(re.findall("[a-zA-Z]+", str(row["keywords"])))
  calories = row["calories"]
  fatContent = row["fatContent"]
  proteinContent = row["proteinContent"]
  data.append([query,recipe_id,recipe_name,Relevance,ingredients,recipe,
               rate,views,description,keywords,calories,fatContent,proteinContent])
new_df = pd.DataFrame(data,columns=["query","docno","recipe_name","Relevance","ingredients","recipe",
               "rate","views","description","keywords","calories","fatContent","proteinContent"])

# %%
new_df.head(6)
# Out:
#     query  docno                                        recipe_name  \
# 0  tomato   6492                              Macaroni and Tomatoes
# 1  tomato  50060                       Tofu Stuffed Cherry Tomatoes
# 2  tomato  54375  Canned Tomatoes Vine Ripened Tomatoes in Tomat...
# 3  tomato  11958                   Chilli Tomato Sauce Tomato Salsa
# 4  tomato  51985                              Cherry Tomato Planets
# 5  tomato  16912         BLANCHING TOMATOES for COOKING amp CANNING
#
#    Relevance                                        ingredients  \
# 0          5  large potatoes teaspoon salt eggs lightly beat...
# 1          5  onion diced garlic cloves minced carrot diced ...
# 2          5  butter recipe cake mix baked in a greased x cm...
# 3          5  large mushrooms cup breadcrumbs cup parmesan c...
# 4          5  teaspoons sesame oil tablespoons gingerroot sh...
# 5          4  ounces large shrimp peeled and deveined tables...
#
#                                               recipe  rate  views  \
# 0  Scrub potatoes well but do not peel In a sauce...   4.5      6
# 1  Sweat onion and garlic in small amount of oil ...   0.0      0
# 2  For best results bake the cake the day before ...   0.0      0
# 3  clean mushrooms with damp cloth remove stems a...   5.0      1
# 4  Place the sesame oil in a hot wok with the gin...   0.0      0
# 5  Heat the oil in a large heavy bottomed skillet...   0.0      0
#
#                                          description  \
# 0  Make and share this Potato Plum Dumplings reci...
# 1  Creamy fat free low cal and a serving of veggi...
# 2  Make and share this Lamingtons recipe from Foo...
# 3  Make and share this Moms Stuffed Mushrooms rec...
# 4  This is from the Donna Hay cookbook quot Cooki...
# 5  Make and share this Cilantro Lime Shrimp recip...
#
#                                             keywords  calories  fatContent  \
# 0  Vegetable Hungarian European Low Protein Healt...     270.6         8.9
# 1  Lactose Free Low Protein Low Cholesterol Egg F...     107.6         0.8
# 2  Low Protein Low Cholesterol Healthy Kid Friend...     179.2         3.1
# 3                      Healthy Mins For Large Groups      16.8         0.7
# 4  Asian Low Protein Low Cholesterol Healthy Mins...      86.8         2.3
# 5                        Very Low Carbs Healthy Mins     165.6         5.4
#
#    proteinContent
# 0             5.8
# 1             3.8
# 2             1.3
# 3             1.4
# 4             0.5
# 5            24.6

# %%
data=[]
foodresults["docno"] = range(0,len(foodresults))
foodresults["recipe_id"] = range(0,len(foodresults))
foodresults.head(5)
for index,row in foodresults.iterrows():
  docno = "d"+str(row["docno"])
  recipe_id = str(row["recipe_id"])
  recipe_name = " ".join(re.findall("[a-zA-Z]+", row["name"]))
  ingredients = " ".join(re.findall("[a-zA-Z]+", str(row["ingredients"])))
  recipe = " ".join(re.findall("[a-zA-Z]+", str(row["recipe"])))
  rate = str(int(row["rate"]))
  views = str(int(row["views"]))
  description = " ".join(re.findall("[a-zA-Z]+", row["description"]))
  keywords = " ".join(re.findall("[a-zA-Z]+", str(row["keywords"])))
  calories = row["calories"]
  fatContent = row["fatContent"]
  proteinContent = row["proteinContent"]
  data.append([recipe_id,recipe_name,ingredients,recipe,
               rate,views,description,keywords,calories,fatContent,proteinContent])
whole_df = pd.DataFrame(data,columns=["docno","recipe_name","ingredients","recipe",
               "rate","views","description","keywords","calories","fatContent","proteinContent"])

# %%
whole_df.head(5)
# Out:
#   docno                             recipe_name  \
# 0     0                      Chinese Fried Rice
# 1     1                 Perfect Pork Tenderloin
# 2     2                   Pulled Pork Crock Pot
# 3     3  The Most Wonderful Gingerbread Cookies
# 4     4               Restaurant Teriyaki Sauce
#
#                                          ingredients  \
# 0  cup finely chopped onion tablespoons oil egg l...
# 1  lb boneless pork tenderloin salt and pepper dr...
# 2  lbs pork roast shoulder or butt large onions c...
# 3  cups all purpose flour teaspoons baking powder...
# 4  cup soy sauce cup water teaspoon ground ginger...
#
#                                               recipe rate views  \
# 0  Heat tbsp oil in wok add chopped onions and st...    5   541
# 1  NOTE nbsp The success of this cooking method w...    5   434
# 2  Slice one onion and place in crock pot Put in ...    5   642
# 3  In a small bowl whisk together flour baking po...    4   559
# 4  Mix all but cornstarch and c water in a sauce ...    5   341
#
#                                          description  \
# 0  This Chinese fried rice has the flavor those o...
# 1  My way to cook a pork tenderloin or a boneless...
# 2  I found this pulled pork recipe years ago and ...
# 3  This is my very favorite gingerbread cookie re...
# 4  You know the nice sweet thick Teriyaki sauce y...
#
#                                             keywords calories fatContent  \
# 0  Pork Poultry Rice Meat Chinese Asian Low Chole...    497.8       16.3
# 1  Meat Very Low Carbs High Protein Healthy High ...    136.2          4
# 2                    Meat Healthy Beginner Cook Easy    335.1        6.9
# 3        Cookie Brownie Healthy Christmas Oven Hours    134.2        3.2
# 4      Low Protein Low Cholesterol Healthy Mins Easy    290.5        0.1
#
#   proteinContent
# 0           22.3
# 1           23.4
# 2           40.2
# 3            1.9
# 4            5.3

# %%
whole_index_dir = "./whole_docs_index"
whole_indexer = pt.DFIndexer(whole_index_dir, overwrite=True)
whole_index_ref = whole_indexer.index(whole_df["recipe"], whole_df["docno"],
                    whole_df["recipe_name"], whole_df["keywords"], 
                    whole_df["description"], whole_df["ingredients"],
                    whole_df["rate"],whole_df["views"])
whole_index_ref.toString()
# Out:
# 01:26:15.443 [main] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (35294) - further warnings are suppressed
# 01:26:31.181 [main] WARN org.terrier.structures.indexing.Indexer - Indexed 1 empty documents
# './whole_docs_index/data.properties'

# %%
whole_index = pt.IndexFactory.of(whole_index_ref)

# %%
topics = pd.read_csv("topics.csv")
qrels = pd.read_csv("qrel.csv")
qrels = qrels.drop(columns=["iteration"])

# %%
topics.head(5)
# Out:
#    qid          query
# 0    1          apple
# 1    2          bacon
# 2    3    baking soda
# 3    4  barbecue ribs
# 4    5           beef

# %%
topics["qid"] = topics["qid"].astype(str)

# %%
topics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   qid     30 non-null     object
#  1   query   30 non-null     object
# dtypes: object(2)
# memory usage: 608.0+ bytes

# %%
qrels["qid"] = qrels["qid"].astype(str)
qrels["docno"] = qrels["docno"].astype(str)

# %% [markdown]
# **Machine Learning**

# %%
# constants
RANK_CUTOFF = 100

# %%
bm25 = pt.BatchRetrieve(whole_index, wmodel="BM25")
tfidf = pt.BatchRetrieve(whole_index, wmodel="TF_IDF")
sdm = pt.rewrite.SDM()
qe = pt.rewrite.Bo1QueryExpansion(whole_index)
query_expansion = bm25>>qe>>bm25
# TODO:
# 增加feature:"optional" not in ingredients
# 增加feature:"of choice" not in ingredients
ltr_feats_new1 = (bm25 % RANK_CUTOFF) >> pt.text.get_text(whole_index, ["recipe_name","keywords","description","ingredients","rate","views"]) >> (
    pt.transformer.IdentityTransformer()
    ** 
    (pt.text.scorer(body_attr="recipe_name", takes='docs', wmodel='BM25'))
    **
    (pt.text.scorer(body_attr="keywords", takes='docs', wmodel='BM25'))
    ** 
    (pt.text.scorer(body_attr="description", takes='docs', wmodel='BM25'))
    ** 
    (pt.text.scorer(body_attr="ingredients", takes='docs', wmodel='BM25'))
    **
    pt.apply.doc_score(lambda row: int(row["rate"]))
    **
    pt.apply.doc_score(lambda row: int(row["views"]))
    **
    query_expansion
    **
    (pt.apply.doc_score(lambda row: int("optional" not in row["ingredients"])))
    **
    (pt.apply.doc_score(lambda row: int("of choice" not in row["ingredients"])))
)

# for reference, lets record the feature names here too
fnames=["f1","f2"]

# %%
SEED=42

from sklearn.model_selection import train_test_split

tr_va_topics, test_topics = train_test_split(topics, test_size=0.15, random_state=SEED)
train_topics, valid_topics =  train_test_split(tr_va_topics, test_size=0.17, random_state=SEED)

# %%
len(train_topics)
# Out:
# 20

# %%
len(test_topics)
# Out:
# 5

# %%
len(valid_topics)
# Out:
# 5

# %%
from sklearn.ensemble import RandomForestRegressor
pipeline = pt.FeaturesBatchRetrieve(whole_index, wmodel="BM25", features=["WMODEL:Tf"])
rf = RandomForestRegressor(n_estimators=400, verbose=1, random_state=42, n_jobs=2)
rf_pipe = ltr_feats_new1 >> pt.ltr.apply_learned_model(rf)
# %time rf_pipe.fit(train_topics, qrels)
# Out:
# 01:26:38.377 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:26:40.029 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:26:41.422 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:26:42.894 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:798: UserWarning: Got number of results different expected from ComposedPipeline(ComposedPipeline(BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'}), QueryExpansion(/content/whole_docs_index/data.properties,3,10,<org.terrier.querying.QueryExpansion at 0x7f72850e3ef0 jclass=org/terrier/querying/QueryExpansion jself=<LocalRef obj=0x4e854e0 at 0x7f72856662d0>>)), BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'})), expected 2000 received 20000, feature scores for any missing documents be 0, extraneous documents will be removed
#   "missing documents be 0, extraneous documents will be removed" % (repr(m), num_results, len(res)))
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    1.0s
# CPU times: user 21.9 s, sys: 448 ms, total: 22.4 s
# Wall time: 15.5 s
# [Parallel(n_jobs=2)]: Done 400 out of 400 | elapsed:    2.0s finished

# %%
import lightgbm as lgb

# this configures LightGBM as LambdaMART
lmart_l = lgb.LGBMRanker(
    task="train",
    silent=False,
    min_data_in_leaf=1,
    min_sum_hessian_in_leaf=1,
    max_bin=255,
    num_leaves=31,
    objective="lambdarank",
    metric="ndcg",
    ndcg_eval_at=[10],
    ndcg_at=[10],
    eval_at=[10],
    learning_rate= .1,
    importance_type="gain",
    num_iterations=100,
    early_stopping_rounds=5
)

lmart_x_pipe = ltr_feats_new1 >> pt.ltr.apply_learned_model(lmart_l, form="ltr", fit_kwargs={'eval_at':[10]})

# %time lmart_x_pipe.fit(train_topics, qrels, valid_topics, qrels)
# Out:
# 01:26:53.199 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:26:54.367 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:26:55.685 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:26:57.029 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:798: UserWarning: Got number of results different expected from ComposedPipeline(ComposedPipeline(BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'}), QueryExpansion(/content/whole_docs_index/data.properties,3,10,<org.terrier.querying.QueryExpansion at 0x7f72850e3ef0 jclass=org/terrier/querying/QueryExpansion jself=<LocalRef obj=0x4e854e0 at 0x7f72856662d0>>)), BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'})), expected 2000 received 20000, feature scores for any missing documents be 0, extraneous documents will be removed
#   "missing documents be 0, extraneous documents will be removed" % (repr(m), num_results, len(res)))
# 01:27:02.460 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:02.824 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:03.205 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:03.595 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:798: UserWarning: Got number of results different expected from ComposedPipeline(ComposedPipeline(BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'}), QueryExpansion(/content/whole_docs_index/data.properties,3,10,<org.terrier.querying.QueryExpansion at 0x7f72850e3ef0 jclass=org/terrier/querying/QueryExpansion jself=<LocalRef obj=0x4e854e0 at 0x7f72856662d0>>)), BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'})), expected 428 received 5000, feature scores for any missing documents be 0, extraneous documents will be removed
#   "missing documents be 0, extraneous documents will be removed" % (repr(m), num_results, len(res)))
# [1]	valid_0's ndcg@10: 0.624649
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's ndcg@10: 0.845078
# [3]	valid_0's ndcg@10: 0.831362
# [4]	valid_0's ndcg@10: 0.831634
# [5]	valid_0's ndcg@10: 0.833933
# [6]	valid_0's ndcg@10: 0.821639
# [7]	valid_0's ndcg@10: 0.817105
# Early stopping, best iteration is:
# [2]	valid_0's ndcg@10: 0.845078
# CPU times: user 18.8 s, sys: 365 ms, total: 19.1 s
# Wall time: 15.2 s
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
feature_names = ["bm25","recipe name","keywords","description","ingredients","rate","views","query expansion"]
print("*************** this is rf ***************")
for i in range(len(feature_names)):
  print(f"feature: {feature_names[i]}, importance: {rf.feature_importances_[i]}")
print("*************** this is lgbm ***************")
for i in range(len(feature_names)):
  print(f"feature: {feature_names[i]}, importance: {lmart_l.feature_importances_[i]}")
# Out:
# *************** this is rf ***************
# feature: bm25, importance: 0.17482862106891925
# feature: recipe name, importance: 0.2854288082047181
# feature: keywords, importance: 0.014939548829194784
# feature: description, importance: 0.043344769287297163
# feature: ingredients, importance: 0.21844544423759926
# feature: rate, importance: 0.01392457343289825
# feature: views, importance: 0.029904917306913175
# feature: query expansion, importance: 0.21250756517632813
# *************** this is lgbm ***************
# feature: bm25, importance: 954.4024213552475
# feature: recipe name, importance: 1540.623443722725
# feature: keywords, importance: 0.0
# feature: description, importance: 177.4875726699829
# feature: ingredients, importance: 1042.818099141121
# feature: rate, importance: 39.58539962768555
# feature: views, importance: 6.245620012283325
# feature: query expansion, importance: 588.4044287204742

# %%
pt.Experiment(
    [rf_pipe % 50,lmart_x_pipe, bm25 % 50, tfidf % 50],
    test_topics,
    qrels,
    eval_metrics=["map", "ndcg"],
    names=["rf model","lgbm model","bm25","tfidf"],
)
# Out:
# 01:27:07.725 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:08.161 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:08.601 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:09.049 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:798: UserWarning: Got number of results different expected from ComposedPipeline(ComposedPipeline(BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'}), QueryExpansion(/content/whole_docs_index/data.properties,3,10,<org.terrier.querying.QueryExpansion at 0x7f72850e3ef0 jclass=org/terrier/querying/QueryExpansion jself=<LocalRef obj=0x4e854e0 at 0x7f72856662d0>>)), BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'})), expected 500 received 5000, feature scores for any missing documents be 0, extraneous documents will be removed
#   "missing documents be 0, extraneous documents will be removed" % (repr(m), num_results, len(res)))
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 400 out of 400 | elapsed:    0.1s finished
# 01:27:11.667 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:12.063 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:12.482 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:27:12.946 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:798: UserWarning: Got number of results different expected from ComposedPipeline(ComposedPipeline(BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'}), QueryExpansion(/content/whole_docs_index/data.properties,3,10,<org.terrier.querying.QueryExpansion at 0x7f72850e3ef0 jclass=org/terrier/querying/QueryExpansion jself=<LocalRef obj=0x4e854e0 at 0x7f72856662d0>>)), BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'})), expected 500 received 5000, feature scores for any missing documents be 0, extraneous documents will be removed
#   "missing documents be 0, extraneous documents will be removed" % (repr(m), num_results, len(res)))
#          name       map      ndcg
# 0    rf model  0.313587  0.462119
# 1  lgbm model  0.442752  0.594658
# 2        bm25  0.322835  0.459698
# 3       tfidf  0.322784  0.456820

# %%
def process_results(query_results, whole_df):
  rank = 0
  results = []
  for result in query_results:
    result_dict = {'docno': result, 
            'recipe_name': whole_df[whole_df['docno'] == result]['recipe_name'].to_list()[0],
            'ingredients': whole_df[whole_df['docno'] == result]['ingredients'].to_list()[0],
            'recipe': whole_df[whole_df['docno'] == result]['recipe'].to_list()[0],
            'rate': whole_df[whole_df['docno'] == result]['rate'].to_list()[0],
            'views': whole_df[whole_df['docno'] == result]['views'].to_list()[0],
            'description': whole_df[whole_df['docno'] == result]['description'].to_list()[0],
            'calories': whole_df[whole_df['docno'] == result]['calories'].to_list()[0],
            'fatContent': whole_df[whole_df['docno'] == result]['fatContent'].to_list()[0],
            'proteinContent': whole_df[whole_df['docno'] == result]['proteinContent'].to_list()[0],
            #'url': whole_df[whole_df['docno'] == result]['url'].to_list()[0],
            'rank': rank}
    results.append(result_dict)
    rank += 1
  return results

# %%
QUERY_CUTOFF = 10
query = "bread lettuce"
query_results = lmart_x_pipe(query).head(QUERY_CUTOFF)["docno"].to_list()
results = process_results(query_results, whole_df)
df = pd.DataFrame(results)
df.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:581: FutureWarning: .transform() should be passed a dataframe. Use .search() to execute a single query.
#   res = self.transformer.transform(topics_and_res)
# 01:31:26.043 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:31:26.311 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:31:26.560 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# 01:31:26.822 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# /usr/local/lib/python3.7/dist-packages/pyterrier/transformer.py:798: UserWarning: Got number of results different expected from ComposedPipeline(ComposedPipeline(BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'}), QueryExpansion(/content/whole_docs_index/data.properties,3,10,<org.terrier.querying.QueryExpansion at 0x7f72850e3ef0 jclass=org/terrier/querying/QueryExpansion jself=<LocalRef obj=0x4e854e0 at 0x7f72856662d0>>)), BR(/content/whole_docs_index/data.properties,{'terrierql': 'on', 'parsecontrols': 'on', 'parseql': 'on', 'applypipeline': 'on', 'localmatching': 'on', 'filters': 'on', 'decorate': 'on', 'wmodel': 'BM25'},{'querying.processes': 'terrierql:TerrierQLParser,parsecontrols:TerrierQLToControls,parseql:TerrierQLToMatchingQueryTerms,matchopql:MatchingOpQLParser,applypipeline:ApplyTermPipeline,context_wmodel:org.terrier.python.WmodelFromContextProcess,localmatching:LocalManager$ApplyLocalMatching,qe:QueryExpansion,labels:org.terrier.learning.LabelDecorator,filters:LocalManager$PostFilterProcess,decorate:SimpleDecorateProcess', 'querying.postfilters': 'decorate:SimpleDecorate,site:SiteFilter,scope:Scope', 'querying.default.controls': 'wmodel:DPH,parsecontrols:on,parseql:on,applypipeline:on,terrierql:on,localmatching:on,filters:on,decorate:on', 'querying.allowed.controls': 'scope,qe,qemodel,start,end,site,scope,applypipeline', 'termpipelines': 'Stopwords,PorterStemmer'})), expected 100 received 1000, feature scores for any missing documents be 0, extraneous documents will be removed
#   "missing documents be 0, extraneous documents will be removed" % (repr(m), num_results, len(res)))
#    docno                                        recipe_name  \
# 0   4553                          Hot Layered Hero Sandwich
# 1    859  Catherine Ann s Enticing Tuna Salad the Longme...
# 2  51948                  Ham Lettuce amp Vegemite Sandwich
# 3  24222                                     Salad Sandwich
# 4  46226          Peanut Butter Lettuce and Tomato Sandwich
#
#                                          ingredients  \
# 0  honey mustard as desired lb thinly sliced deli...
# 1  ounces canned tuna in water or oil drained lar...
# 2  slices bread butter to spread vegemite to spre...
# 3  slices white bread tablespoon Russian salad dr...
# 4  slices bread or slices rolls tablespoons peanu...
#
#                                               recipe rate views  \
# 0  Cut bread in half carefully hollow out part of...    5     5
# 1  Mix together celery mustard onion mayonnaise p...    5    26
# 2  Spread the bread with butter and Vegemite Laye...    0     0
# 3  Spread the dressing on one slice of bread Plac...    5     1
# 4  Add the peanut butter to one side of bread or ...    0     0
#
#                                          description calories fatContent  \
# 0  This sandwich makes a great meal while watchin...      489       21.6
# 1  This recipe was saved from many years ago when...      330       11.4
# 2  This is something I came up with when I was a ...    195.4        6.1
# 3  Just what the title says salad in a sandwich T...    201.9        5.7
# 4  I loved blt s but when I became a vegetarian I...    344.3         18
#
#   proteinContent  rank
# 0           27.6     0
# 1           24.5     1
# 2            7.9     2
# 3            4.8     3
# 4             13     4

# %%
# Out:
#    docno                                        recipe_name  \
# 0   4553                          Hot Layered Hero Sandwich
# 1    859  Catherine Ann s Enticing Tuna Salad the Longme...
# 2  51948                  Ham Lettuce amp Vegemite Sandwich
# 3  24222                                     Salad Sandwich
# 4  46226          Peanut Butter Lettuce and Tomato Sandwich
#
#                                          ingredients  \
# 0  honey mustard as desired lb thinly sliced deli...
# 1  ounces canned tuna in water or oil drained lar...
# 2  slices bread butter to spread vegemite to spre...
# 3  slices white bread tablespoon Russian salad dr...
# 4  slices bread or slices rolls tablespoons peanu...
#
#                                               recipe rate views  \
# 0  Cut bread in half carefully hollow out part of...    5     5
# 1  Mix together celery mustard onion mayonnaise p...    5    26
# 2  Spread the bread with butter and Vegemite Laye...    0     0
# 3  Spread the dressing on one slice of bread Plac...    5     1
# 4  Add the peanut butter to one side of bread or ...    0     0
#
#                                          description calories fatContent  \
# 0  This sandwich makes a great meal while watchin...      489       21.6
# 1  This recipe was saved from many years ago when...      330       11.4
# 2  This is something I came up with when I was a ...    195.4        6.1
# 3  Just what the title says salad in a sandwich T...    201.9        5.7
# 4  I loved blt s but when I became a vegetarian I...    344.3         18
#
#   proteinContent  rank
# 0           27.6     0
# 1           24.5     1
# 2            7.9     2
# 3            4.8     3
# 4             13     4
